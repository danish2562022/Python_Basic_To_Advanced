# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x=[23,24,25,26]
y=[1000,2000,3000,1900]
y2=[500,1500,2500,3500]
y3=[0,200,300,4000]

# %%
plt.bar(x,y,label="y")
plt.xlabel('ages')
plt.ylabel('salary')
plt.title("Salary vs age")
plt.bar(x,y2,label="y1")
plt.legend()
plt.show()

# %%
x_indexes=np.arange(len(x))

# %%
plt.bar(x_indexes-width,y,width=0.25,label="y")
plt.xlabel('ages')
plt.ylabel('salary')
plt.title("Salary vs age")
plt.bar(x_indexes,y2,width=0.25,label="y1")
plt.bar(x_indexes+width,y3,width=0.25,label="y3")
plt.xticks(ticks=x_indexes,labels=x)
plt.legend()
plt.show()
