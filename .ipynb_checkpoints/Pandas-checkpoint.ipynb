# %%
import pandas as pd

# %%
df=pd.read_csv('annualreport.csv')

# %%
df.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
df.shape
# Out:
# (13932, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13932 entries, 0 to 13931
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  13932 non-null  int64
#  1   industry_code_ANZSIC  13932 non-null  object
#  2   industry_name_ANZSIC  13932 non-null  object
#  3   rme_size_grp          13932 non-null  object
#  4   variable              13932 non-null  object
#  5   value                 13932 non-null  object
#  6   unit                  13932 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 762.0+ KB

# %%
person={
     "first":"Danish",
     "last":"Anwer",
    "email":"Danish@gmail.com"
}

# %%
people={
     "first":["Danish"],
     "last":["Anwer"],
    "email":["Danish@gmail.com"]
}

# %%
people={
     "first":["Danish","Sanketa","Hari"],
     "last":["Anwer","Hegde","Vishnu"],
    "email":["Danish@gmail.com","sanketa@gmail.com","vishnu@gmail.com"]
}

# %%
people["email"]
# Out:
# ['Danish@gmail.com', 'sanketa@gmail.com', 'vishnu@gmail.com']

# %%
data=pd.DataFrame(people)

# %%
data.head()
# Out:
#      first    last              email
# 0   Danish   Anwer   Danish@gmail.com
# 1  Sanketa   Hegde  sanketa@gmail.com
# 2     Hari  Vishnu   vishnu@gmail.com

# %%
data["email"]
# Out:
# 0     Danish@gmail.com
# 1    sanketa@gmail.com
# 2     vishnu@gmail.com
# Name: email, dtype: object

# %%
type(data["email"])
# Out:
# pandas.core.series.Series

# %%
data.shape
# Out:
# (3, 3)

# %%
data.email
# Out:
# 0     Danish@gmail.com
# 1    sanketa@gmail.com
# 2     vishnu@gmail.com
# Name: email, dtype: object

# %%
data[['email','first']]
# Out:
#                email    first
# 0   Danish@gmail.com   Danish
# 1  sanketa@gmail.com  Sanketa
# 2   vishnu@gmail.com     Hari

# %%
data.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
#loc and iloc

data.iloc[0]
# Out:
# first              Danish
# last                Anwer
# email    Danish@gmail.com
# Name: 0, dtype: object

# %%
data.iloc[2]
# Out:
# first                Hari
# last               Vishnu
# email    vishnu@gmail.com
# Name: 2, dtype: object

# %%
data.iloc[[2,0]]
# Out:
#     first    last             email
# 2    Hari  Vishnu  vishnu@gmail.com
# 0  Danish   Anwer  Danish@gmail.com

# %%
data.iloc[[2,0],[2]]
# Out:
#               email
# 2  vishnu@gmail.com
# 0  Danish@gmail.com

# %%
data.head()
# Out:
#      first    last              email
# 0   Danish   Anwer   Danish@gmail.com
# 1  Sanketa   Hegde  sanketa@gmail.com
# 2     Hari  Vishnu   vishnu@gmail.com

# %%
data.loc[0]
# Out:
# first              Danish
# last                Anwer
# email    Danish@gmail.com
# Name: 0, dtype: object

# %%
data.loc[[0,2]]
# Out:
#     first    last             email
# 0  Danish   Anwer  Danish@gmail.com
# 2    Hari  Vishnu  vishnu@gmail.com

# %%
data.loc[[0,2],'email']
# Out:
# 0    Danish@gmail.com
# 2    vishnu@gmail.com
# Name: email, dtype: object

# %%
data.loc[[0,2],['email','last']]
# Out:
#               email    last
# 0  Danish@gmail.com   Anwer
# 2  vishnu@gmail.com  Vishnu

# %%
df.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
df.shape
# Out:
# (13932, 7)

# %%
df['variable']
# Out:
# 0                                          Activity unit
# 1                                 Rolling mean employees
# 2                                Salaries and wages paid
# 3        Sales, government funding, grants and subsidies
# 4                                           Total income
#                               ...
# 13927                                       Total income
# 13928                                  Total expenditure
# 13929                        Operating profit before tax
# 13930                                       Total assets
# 13931                              Fixed tangible assets
# Name: variable, Length: 13932, dtype: object

# %%
df['year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 13927    2019
# 13928    2019
# 13929    2019
# 13930    2019
# 13931    2019
# Name: year, Length: 13932, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2015    1548
# 2014    1548
# 2013    1548
# 2012    1548
# 2019    1548
# 2011    1548
# 2018    1548
# 2017    1548
# 2016    1548
# Name: year, dtype: int64

# %%
df.loc[0]
# Out:
# year                                                 2011
# industry_code_ANZSIC                                    A
# industry_name_ANZSIC    Agriculture, Forestry and Fishing
# rme_size_grp                                          a_0
# variable                                    Activity unit
# value                                               46134
# unit                                                COUNT
# Name: 0, dtype: object

# %%
df.loc[[0],'year']
# Out:
# 0    2011
# Name: year, dtype: int64

# %%
df.loc[[0],['year','variable']]
# Out:
#    year       variable
# 0  2011  Activity unit

# %%
df.loc[0:2,'year':'value']
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                   variable  value
# 0            Activity unit  46134
# 1   Rolling mean employees      0
# 2  Salaries and wages paid    279

# %%
data
# Out:
#      first    last              email
# 0   Danish   Anwer   Danish@gmail.com
# 1  Sanketa   Hegde  sanketa@gmail.com
# 2     Hari  Vishnu   vishnu@gmail.com

# %%
data['email']
# Out:
# 0     Danish@gmail.com
# 1    sanketa@gmail.com
# 2     vishnu@gmail.com
# Name: email, dtype: object

# %%
data.set_index('email') # not inplace
# Out:
#                      first    last
# email
# Danish@gmail.com    Danish   Anwer
# sanketa@gmail.com  Sanketa   Hegde
# vishnu@gmail.com      Hari  Vishnu

# %%
data.head()
# Out:
#      first    last              email
# 0   Danish   Anwer   Danish@gmail.com
# 1  Sanketa   Hegde  sanketa@gmail.com
# 2     Hari  Vishnu   vishnu@gmail.com

# %%
data.set_index('email',inplace=True)

# %%
data
# Out:
#                      first    last
# email
# Danish@gmail.com    Danish   Anwer
# sanketa@gmail.com  Sanketa   Hegde
# vishnu@gmail.com      Hari  Vishnu

# %%
data.index
# Out:
# Index(['Danish@gmail.com', 'sanketa@gmail.com', 'vishnu@gmail.com'], dtype='object', name='email')

# %%
data.loc[0] # error will be thrown because there is no index '0' in dataframe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-7be82026b0ee> in <module>
# ----> 1 data.loc[0] # error will be thrown because there is no index '0' in dataframe
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1962
#    1963         # fall thru to straight lookup
# -> 1964         self._validate_key(key, axis)
#    1965         return self._get_label(key, axis=axis)
#    1966
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1829
#    1830         if not is_list_like_indexer(key):
# -> 1831             self._convert_scalar_indexer(key, axis)
#    1832
#    1833     def _is_scalar_access(self, key: Tuple) -> bool:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_scalar_indexer(self, key, axis)
#     739         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     740         # a scalar
# --> 741         return ax._convert_scalar_indexer(key, kind=self.name)
#     742
#     743     def _convert_slice_indexer(self, key: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_scalar_indexer(self, key, kind)
#    2886             elif kind in ["loc"] and is_integer(key):
#    2887                 if not self.holds_integer():
# -> 2888                     self._invalid_indexer("label", key)
#    2889
#    2890         return key
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3074         Consistent invalid indexer message.
#    3075         """
# -> 3076         raise TypeError(
#    3077             f"cannot do {form} indexing on {type(self)} with these "
#    3078             f"indexers [{key}] of {type(key)}"
#
# TypeError: cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %%
data.loc['Danish@gmail.com']
# Out:
# first    Danish
# last      Anwer
# Name: Danish@gmail.com, dtype: object

# %%
data.loc['Danish@gmail.com','last']
# Out:
# 'Anwer'

# %%
data.iloc[0]
# Out:
# first    Danish
# last      Anwer
# Name: Danish@gmail.com, dtype: object

# %%
data.reset_index(inplace=True)
data.head()
# Out:
#                email    first    last
# 0   Danish@gmail.com   Danish   Anwer
# 1  sanketa@gmail.com  Sanketa   Hegde
# 2   vishnu@gmail.com     Hari  Vishnu

# %%
df=pd.read_csv('annualreport.csv',index_col='year')

# %%
df.head()
# Out:
#      industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# year
# 2011                    A  Agriculture, Forestry and Fishing          a_0
# 2011                    A  Agriculture, Forestry and Fishing          a_0
# 2011                    A  Agriculture, Forestry and Fishing          a_0
# 2011                    A  Agriculture, Forestry and Fishing          a_0
# 2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                              variable  value  \
# year
# 2011                                    Activity unit  46134
# 2011                           Rolling mean employees      0
# 2011                          Salaries and wages paid    279
# 2011  Sales, government funding, grants and subsidies   8187
# 2011                                     Total income   8866
#
#                    unit
# year
# 2011              COUNT
# 2011              COUNT
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)

# %%
df.loc[2011]
# Out:
#      industry_code_ANZSIC               industry_name_ANZSIC   rme_size_grp  \
# year
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# ...                   ...                                ...            ...
# 2011                  all                     All Industries  j_Grand_Total
# 2011                  all                     All Industries  j_Grand_Total
# 2011                  all                     All Industries  j_Grand_Total
# 2011                  all                     All Industries  j_Grand_Total
# 2011                  all                     All Industries  j_Grand_Total
#
#                                              variable    value  \
# year
# 2011                                    Activity unit    46134
# 2011                           Rolling mean employees        0
# 2011                          Salaries and wages paid      279
# 2011  Sales, government funding, grants and subsidies     8187
# 2011                                     Total income     8866
# ...                                               ...      ...
# 2011                                     Total income   510905
# 2011                                Total expenditure   468838
# 2011                      Operating profit before tax    46348
# 2011                                     Total assets  1662320
# 2011                            Fixed tangible assets   366725
#
#                    unit
# year
# 2011              COUNT
# 2011              COUNT
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# ...                 ...
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
#
# [1548 rows x 6 columns]

# %%
people={
     "first":["Danish","Sanketa","Hari"],
     "last":["Anwer","Hegde","Hegde"],
    "email":["Danish@gmail.com","sanketa@gmail.com","vishnu@gmail.com"]
}

# %%
data=pd.DataFrame(people)
data.head()
# Out:
#      first   last              email
# 0   Danish  Anwer   Danish@gmail.com
# 1  Sanketa  Hegde  sanketa@gmail.com
# 2     Hari  Hegde   vishnu@gmail.com

# %%
data['last']=='Hegde'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt=data['last']=='Hegde'

# %%
data[filt]
# Out:
#      first   last              email
# 1  Sanketa  Hegde  sanketa@gmail.com
# 2     Hari  Hegde   vishnu@gmail.com

# %%
data[data['last']=='Hegde']
# Out:
#      first   last              email
# 1  Sanketa  Hegde  sanketa@gmail.com
# 2     Hari  Hegde   vishnu@gmail.com

# %%
data.loc[filt]
# Out:
#      first   last              email
# 1  Sanketa  Hegde  sanketa@gmail.com
# 2     Hari  Hegde   vishnu@gmail.com

# %%
data.loc[filt,'email']
# Out:
# 1    sanketa@gmail.com
# 2     vishnu@gmail.com
# Name: email, dtype: object

# %%
filt=(data['last']=='Hegde') & (data['first']=='Sanketa')
filt
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
data.loc[filt]
# Out:
#      first   last              email
# 1  Sanketa  Hegde  sanketa@gmail.com

# %%
df.head()
# Out:
#      industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# year
# 2011                    A  Agriculture, Forestry and Fishing          a_0
# 2011                    A  Agriculture, Forestry and Fishing          a_0
# 2011                    A  Agriculture, Forestry and Fishing          a_0
# 2011                    A  Agriculture, Forestry and Fishing          a_0
# 2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                              variable  value  \
# year
# 2011                                    Activity unit  46134
# 2011                           Rolling mean employees      0
# 2011                          Salaries and wages paid    279
# 2011  Sales, government funding, grants and subsidies   8187
# 2011                                     Total income   8866
#
#                    unit
# year
# 2011              COUNT
# 2011              COUNT
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)

# %%
filt=(df['value']>='4000')

# %%
df.loc[filt]
# Out:
#      industry_code_ANZSIC               industry_name_ANZSIC   rme_size_grp  \
# year
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# 2011                    A  Agriculture, Forestry and Fishing            a_0
# ...                   ...                                ...            ...
# 2019                  all                     All Industries  j_Grand_Total
# 2019                  all                     All Industries  j_Grand_Total
# 2019                  all                     All Industries  j_Grand_Total
# 2019                  all                     All Industries  j_Grand_Total
# 2019                  all                     All Industries  j_Grand_Total
#
#                                              variable   value  \
# year
# 2011                                    Activity unit   46134
# 2011  Sales, government funding, grants and subsidies    8187
# 2011                                     Total income    8866
# 2011                                Total expenditure    7618
# 2011                      Operating profit before tax     770
# ...                                               ...     ...
# 2019  Sales, government funding, grants and subsidies  643809
# 2019                                     Total income  728239
# 2019                                Total expenditure  634710
# 2019                      Operating profit before tax   86426
# 2019                            Fixed tangible assets  535710
#
#                    unit
# year
# 2011              COUNT
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# 2011  DOLLARS(millions)
# ...                 ...
# 2019  DOLLARS(millions)
# 2019  DOLLARS(millions)
# 2019  DOLLARS(millions)
# 2019  DOLLARS(millions)
# 2019  DOLLARS(millions)
#
# [5866 rows x 6 columns]

# %%
df.loc[filt,['variable','value']].reset_index()
# Out:
#       year                                         variable   value
# 0     2011                                    Activity unit   46134
# 1     2011  Sales, government funding, grants and subsidies    8187
# 2     2011                                     Total income    8866
# 3     2011                                Total expenditure    7618
# 4     2011                      Operating profit before tax     770
# ...    ...                                              ...     ...
# 5861  2019  Sales, government funding, grants and subsidies  643809
# 5862  2019                                     Total income  728239
# 5863  2019                                Total expenditure  634710
# 5864  2019                      Operating profit before tax   86426
# 5865  2019                            Fixed tangible assets  535710
#
# [5866 rows x 3 columns]

# %%
data
# Out:
#      first   last              email
# 0   Danish  Anwer   Danish@gmail.com
# 1  Sanketa  Hegde  sanketa@gmail.com
# 2     Hari  Hegde   vishnu@gmail.com

# %%
data.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
data.columns=["first name","last name"," Email Address"]

# %%
data
# Out:
#   first name last name      Email Address
# 0     Danish     Anwer   Danish@gmail.com
# 1    Sanketa     Hegde  sanketa@gmail.com
# 2       Hari     Hegde   vishnu@gmail.com

# %%
data.columns=data.columns.str.replace(' ','_')
data
# Out:
#   first_name last_name     _Email_Address
# 0     Danish     Anwer   Danish@gmail.com
# 1    Sanketa     Hegde  sanketa@gmail.com
# 2       Hari     Hegde   vishnu@gmail.com
